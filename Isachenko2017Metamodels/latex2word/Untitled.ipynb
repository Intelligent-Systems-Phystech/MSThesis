# %%
from PIL import Image

# %%
img = Image.open('figs/ar_example.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x300 at 0x103C5F240>

# %%
img.convert('LA')
# Out:
# <PIL.Image.Image image mode=LA size=1000x300 at 0x104701C50>
